# %% [markdown]
# # Como pegar cotações de ações com Python

# %% [markdown]
# #### pandas_datareader

# %% [markdown]
# ### Pegando cotação de uma ação

# %%
from pandas_datareader import data as web
import pandas as pd
import matplotlib.pyplot as plt

# %%
cotacao_bovespa = web.DataReader('^BVSP', data_source='yahoo', start='12/01/2020', end='01/01/2021')
cotacao_petrobras = web.DataReader('^PETR4.SA', data_source='yahoo', start='12/01/2020', end='01/01/2021')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas_datareader\yahoo\daily.py in _read_one_data(self, url, params)
#     156             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 157             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     158         except KeyError:
#
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-31-c8bd9cfc945d> in <module>
#       1 cotacao_bovespa = web.DataReader('^BVSP', data_source='yahoo', start='12/01/2020', end='01/01/2021')
# ----> 2 cotacao_petrobras = web.DataReader('^PETR4.SA', data_source='yahoo', start='12/01/2020', end='01/01/2021')
#
# ...

# %%
display(cotacao_bovespa)
# Out:
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2020-12-01  111840  108897  108897  111335  11324800     111335
# 2020-12-02  112315  110579  111402  111814   9814300     111814
# 2020-12-03  113377  111874  111874  112919  11474200     112919
# 2020-12-04  113864  112294  112294  113682   8892900     113682
# 2020-12-07  114531  112629  113751  113625   9633900     113625
# 2020-12-08  114381  112820  113590  113571   8810900     113571
# 2020-12-09  114020  112567  113799  112722   8431100     112722
# 2020-12-10  115262  112732  113002  114992  11803600     114992
# 2020-12-11  115527  113949  115128  115323   8372300     115323
# 2020-12-14  115740  114431  115137  114975   8190900     114975
# 2020-12-15  116390  114613  114613  116146   8195100     116146
# 2020-12-16  118178  115496  116149  117947   9808100     117947
# 2020-12-17  119027  117856  117864  118157   7701400     118157
# 2020-12-18  119370  117639  118395  117679   8636000     117679
# ...

# %%
cotacao_bovespa[["Adj Close", "Open"]].plot(figsize=(15,10), title='Evolução ao longo do tempo')
# Out:
# <AxesSubplot:title={'center':'Evolução ao longo do tempo'}, xlabel='Date'>
